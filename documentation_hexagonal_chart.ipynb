# %%
import static as mu_hex

location = r'C:\Users\timothy\python_program\musical_data1.csv'

# %% [markdown]
# # Hexagonal tonnetz Plot
# List of the parameters of the musical_hex_plot function:
# - location: direct path to the datafile
# - dataType: type of data that the program has to read
# - log: boolean that determines if the color scale is logarithmic or linear
# - convertTable: if the dataType to be read is pitch class, provides a dictionary to the tpc format
# - pitchClassDisplay: boolean that determines if the pie use the pitch class format or the tpc format to represent the notes
# - duplicate: boolean that determines if there can be duplicate of the same note
# - colorbar: boolean that determines of it has to plot the colorbar or note
# - duration: boolean that determines if it has to account of the total duration of the note or the number of time the note appeared
# - figSize: give the size of the plot in inches
# - size: give the number of layers the hexagonal plot must have
# - hexSize: factor to modulate the size of the hexagons, normally at 1
# - textSize: factor to modualte the size of the font for the labels
# - centerNote: give the note that must be in the center of the plot
# - colorGeneral: tell the generalt color or color panel for the graph
# - colorZeroValue: tell the color of the notes that are not represented
# <br>
# <br>
# Default values:

# %%
location
dataType='tpc'
log=False
convertTable=['C', 'Db', 'D', 'Eb', 'E', 'F', 'Gb', 'G', 'Ab', 'A', 'Bb', 'B']
pitchClassDisplay=False
duplicate=True
colorbar=True
duration=False
figSize = 9
size = 3
hexSize = 1
textSize = 1
centerNote = 'nan'
colorGeneral = 'Blues'
colorZeroValue = 'nan'

# %%
mu_hex.hexagonal_chart(location, figSize=5)

# %% [markdown]
# # dataType and pitchClassDisplay

# %%
mu_hex.hexagonal_chart(location, figSize=5, dataType='tpc', pitchClassDisplay=False)

# %%
mu_hex.hexagonal_chart(location, figSize=5, dataType='pc', pitchClassDisplay=True)

# %% [markdown]
# # figSize, colorbar, colorGeneral and colorZeroValue

# %%
mu_hex.hexagonal_chart(location, figSize=5, colorbar=True, colorGeneral='Blues', colorZeroValue='nan')

# %%
mu_hex.hexagonal_chart(location, figSize=4, colorbar=False, colorGeneral='Reds', colorZeroValue='Grey')

# %% [markdown]
# ## log, duration, centerNote, size and duplicate

# %%
mu_hex.hexagonal_chart(location, figSize=5, log=False, duration=False, centerNote='nan', size=3, duplicate=True)

# %%
mu_hex.hexagonal_chart(location, figSize=5, log=True, duration=True, centerNote='C', size=5, duplicate=False)

# %%
mu_hex.hexagonal_chart(location, figSize=5, dataType='pc', pitchClassDisplay=True, log=True, duration=True, centerNote=5, duplicate=False)

# %% [markdown]
# ## hexSize and textSize

# %%
mu_hex.hexagonal_chart(location, figSize=5, hexSize=1, textSize=1)

# %%
mu_hex.hexagonal_chart(location, figSize=5, hexSize=1.5, textSize=0.5)

# %% [markdown]
# ## convertTable

# %%
mu_hex.hexagonal_chart(location, figSize=5, dataType='pc', pitchClassDisplay=False, convertTable=['C', 'Db', 'D', 'Eb', 'E', 'F', 'Gb', 'G', 'Ab', 'A', 'Bb', 'B'])

# %%
mu_hex.hexagonal_chart(location, figSize=5, dataType='pc', pitchClassDisplay=False, convertTable=['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B'])
